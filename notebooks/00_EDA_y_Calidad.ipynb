# %% [markdown]
# <a href="https://colab.research.google.com/github/Cacofernando/Proyecto-Integrador-Big-Data-Cloud-Computing/blob/main/notebooks/00_EDA_y_Calidad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 00. Análisis Exploratorio de Datos (EDA) y Auditoría de Calidad
# **Proyecto:** Plataforma Big Data para Analítica Omnicanal de Ventas Retail
# **Curso:** Big Data & Cloud Computing - Magíster en Data Science UDD
# **Integrantes:** Claudio Ballerini, Juan José Torres, Cristian Vargas, Christian Vásquez
# **Fecha:** Junio de 2026
#
# ---
#
# ## 1. Configuración del Entorno (Setup)
# *En esta sección instalamos las dependencias necesarias e inicializamos la sesión de Spark en Google Colab.*

# %%
# 1.1 Instalar PySpark y Delta Lake directamente vía pip (Método moderno y estable)
# !pip install -q pyspark==3.5.0 delta-spark==3.0.0

# 1.2 Autenticación con Google Cloud (Para guardar/leer en Cloud Storage)
from google.colab import auth
auth.authenticate_user()

# 1.3 Inicializar Spark con soporte nativo para Delta Lake
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Ingesta-Bronze-Retail") \
    .config("spark.jars.packages", "io.delta:delta-spark_2.12:3.0.0") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .getOrCreate()

print("Entorno Colab configurado y Spark inicializado con éxito.")
# Out:
# Entorno Colab configurado y Spark inicializado con éxito.

# %% [markdown]
# ## 2. Ingesta de Datos (Lectura desde la Fuente)
# *Aquí conectamos con la fuente original.*

# %%
# EJEMPLO: Si leen desde un dataset público en BigQuery (Estrategia A del curso)
# df_ventas_crudas = spark.read.format("bigquery").option("table", "bigquery-public-data.dataset.tabla").load()

# EJEMPLO: Si generaron datos sintéticos masivos y los tienen en un CSV
# df_ventas_crudas = spark.read.csv("/content/drive/MyDrive/ProyectoBigData/raw/ventas_sinteticas.csv", header=True, inferSchema=True)

# Imprimir el esquema para validar la lectura
df_ventas_crudas.printSchema()
print(f"Total de registros a ingestar: {df_ventas_crudas.count()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6178/1369278541.py in <cell line: 0>()
#       6
#       7 # Imprimir el esquema para validar la lectura
# ----> 8 df_ventas_crudas.printSchema()
#       9 print(f"Total de registros a ingestar: {df_ventas_crudas.count()}")
#
# NameError: name 'df_ventas_crudas' is not defined
